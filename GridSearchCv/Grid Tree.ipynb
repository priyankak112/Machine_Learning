# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
#Prepocessing the dataset using Label Encoding for 2 categorical data
'''sex_mapping={'male':1,'female':0}
smoker_mapping={'yes':1,'no':0}
dataset['sex']=dataset['sex'].replace(sex_mapping)
dataset['smoker']=dataset['smoker'].replace(smoker_mapping)'''
# Out:
# "sex_mapping={'male':1,'female':0}\nsmoker_mapping={'yes':1,'no':0}\ndataset['sex']=dataset['sex'].replace(sex_mapping)\ndataset['smoker']=dataset['smoker'].replace(smoker_mapping)"

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age','bmi','children','sex_male','smoker_yes']]
independent.head()
# Out:
#    age     bmi  children  sex_male  smoker_yes
# 0   19  27.900         0     False        True
# 1   18  33.770         1      True       False
# 2   28  33.000         3      True       False
# 3   33  22.705         0      True       False
# 4   32  28.880         0      True       False

# %%
dependent=dataset[['charges']]
dependent.head()
# Out:
#        charges
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error','absolute_error','friedman_mse'],
            'max_features': ['sqrt','log2'],
           'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid.best_score_
# Out:
# np.float64(0.7016766182896484)

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.016408      0.002319         0.008264        0.001266
# 1        0.014112      0.000778         0.008401        0.000429
# 2        0.020873      0.004672         0.016891        0.008371
# 3        0.020598      0.009297         0.008468        0.002421
# 4        0.047326      0.003798         0.007845        0.000587
# 5        0.035453      0.003875         0.007669        0.000781
# 6        0.047588      0.004894         0.007209        0.000368
# 7        0.040899      0.001849         0.008548        0.001708
# 8        0.015399      0.000767         0.008047        0.000696
# 9        0.013505      0.000497         0.007516        0.000482
# 10       0.015717      0.001936         0.008706        0.001074
# 11       0.013821      0.001231         0.007101        0.000845
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4   absolute_error               sqrt           best
# 5   absolute_error               sqrt         random
# 6   absolute_error               log2           best
# 7   absolute_error               log2         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.734868
# 1   {'criterion': 'squared_error', 'max_features':...           0.675933
# 2   {'criterion': 'squared_error', 'max_features':...           0.668638
# 3   {'criterion': 'squared_error', 'max_features':...           0.701633
# 4   {'criterion': 'absolute_error', 'max_features'...           0.668697
# 5   {'criterion': 'absolute_error', 'max_features'...           0.665853
# 6   {'criterion': 'absolute_error', 'max_features'...           0.744444
# 7   {'criterion': 'absolute_error', 'max_features'...           0.610146
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.720236
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.688341
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.617357
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.698788
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.604351           0.753866           0.718982
# 1            0.488268           0.732384           0.681972
# 2            0.591151           0.725792           0.676542
# 3            0.576046           0.662924           0.630510
# 4            0.442867           0.544041           0.757678
# 5            0.563887           0.379661           0.652538
# 6            0.605516           0.701685           0.643502
# 7            0.547112           0.667152           0.717735
# 8            0.635865           0.731047           0.704344
# 9            0.518474           0.699818           0.637249
# 10           0.626641           0.703164           0.690087
# 11           0.510038           0.695471           0.605983
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.696317         0.701677        0.052203                1
# 1            0.707620         0.657235        0.086830                6
# 2            0.655968         0.663618        0.043284                4
# 3            0.623518         0.638926        0.041881                7
# 4            0.770401         0.636737        0.126248                8
# 5            0.705013         0.593390        0.116413               12
# 6            0.781251         0.695279        0.064168                3
# 7            0.608177         0.630064        0.057998               11
# 8            0.703509         0.699000        0.033205                2
# 9            0.622791         0.633335        0.064444               10
# 10           0.665375         0.660525        0.033844                5
# 11           0.663929         0.634842        0.070739                9

# %%
#final predict
fin_pred=grid.predict([[19,0,27.900,0,1]])
print(f"The final prediction is ${fin_pred}")
# Out:
# The final prediction is $[14455.64405]
# C:\Users\huawei\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
