# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse'],
            'max_features':['sqrt','log2'],
            'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1,cv=3)
grid.fit(indep,dep)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
grid.best_score_
# Out:
# np.float64(0.8316108741175783)

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.081017      0.001879         0.011111        0.001066
# 1        0.573465      0.019467         0.035650        0.002120
# 2        0.076808      0.003113         0.010138        0.001021
# 3        0.521908      0.008372         0.044365        0.003000
# 4        0.147401      0.013670         0.007108        0.000415
# 5        1.304263      0.009408         0.032399        0.000539
# 6        0.154123      0.006309         0.006278        0.000039
# 7        1.277768      0.010690         0.022087        0.002186
# 8        0.052056      0.003206         0.006839        0.000628
# 9        0.451555      0.011152         0.033391        0.001479
# 10       0.050779      0.001710         0.006485        0.000295
# 11       0.388092      0.038529         0.022209        0.004942
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# ...

# %%
fin_pred=grid.predict([[19,0,27.900,0,1]])
print(f"radom Forest gridsearch prediction is:{fin_pred}")
# Out:
# radom Forest gridsearch prediction is:[16860.1899513]
# C:\Users\huawei\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
