# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
X = dataset.iloc[:, [3, 4]].values

# %%
from sklearn.cluster import AffinityPropagation
clustering = AffinityPropagation(random_state=5).fit(X)
label=clustering.fit_predict(X)

# %%
print("cluster centers are:",clustering.cluster_centers_)
print("n_clusters=",len(clustering.cluster_centers_indices_))
# Out:
# cluster centers are: [[ 25   5]
#  [ 28  82]
#  [ 28  32]
#  [ 46  51]
#  [ 60  52]
#  [ 67  40]
#  [ 77  12]
#  [ 78  90]
#  [ 78  73]
#  [103  85]
#  [103  23]]
# n_clusters= 11

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised['cluster_group']=label
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      cluster_group
# 0                2
# 1                1
# 2                0
# 3                1
# 4                2
# ..             ...
# 195              9
# 196             10
# 197              9
# 198             10
# 199              9
#
# [200 rows x 6 columns]

# %%
# Use Seaborn's scatterplot
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x=supervised.columns[3],
    y=supervised.columns[4],
    hue=supervised.columns[5], # Use the new cluster column for color
    data=supervised,
    palette='viridis', # Use a distinct color palette
    legend='full'
)
plt.title('Affinity Propagation Clusters')
plt.show()
