# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('CKD.csv')
dataset.head()
# Out:
#    age         bp sg   al   su     rbc        pc         pcc          ba  \
# 0  2.0  76.459948  c  3.0  0.0  normal  abnormal  notpresent  notpresent
# 1  3.0  76.459948  c  2.0  0.0  normal    normal  notpresent  notpresent
# 2  4.0  76.459948  a  1.0  0.0  normal    normal  notpresent  notpresent
# 3  5.0  76.459948  d  1.0  0.0  normal    normal  notpresent  notpresent
# 4  5.0  50.000000  c  0.0  0.0  normal    normal  notpresent  notpresent
#
#           bgr  ...        pcv            wc        rc  htn  dm  cad  appet  \
# 0  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 1  148.112676  ...  34.000000  12300.000000  4.705597   no  no   no    yes
# 2   99.000000  ...  34.000000   8408.191126  4.705597   no  no   no    yes
# 3  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 4  148.112676  ...  36.000000  12400.000000  4.705597   no  no   no    yes
#
#      pe  ane classification
# 0   yes   no            yes
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
indep
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  rbc_normal  pc_normal  pcc_present  \
# ...

# %%
dep=dataset[['classification_yes']]
dep
# Out:
#      classification_yes
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ..                  ...
# 394                True
# 395                True
# 396                True
# 397                True
# 398               False
#
# [399 rows x 1 columns]

# %%
#finding the row index whichever has false value
false_indices = np.where(dataset[['classification_yes']] == False)
print("Array of indices with False values:")
print(false_indices[0])
# Out:
# Array of indices with False values:
# [ 12  15  18  20  21  22  25  26  27  28  29  31  32  33  34  35  36  39
#   40  41  42  43  45  46  47  48  49  50  52  53  55  56  57  58  59  65
#   66  67  68  71  72  73  74  76  78  79  81  82  84  85  86  89  90  93
#   94  95  98  99 100 101 103 104 105 106 107 109 110 111 112 113 121 122
#  123 130 131 132 138 139 140 141 142 143 152 153 154 156 166 167 168 171
#  172 173 176 177 178 183 193 200 201 202 203 204 205 213 214 215 220 221
#  222 223 225 226 227 228 237 238 254 255 256 257 265 266 275 276 282 283
#  290 291 307 308 312 313 320 328 334 342 343 349 350 351 358 365 366 369
#  373 374 381 384 385 398]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train[15] #train dataset row whcih has false value as output
# Out:
# array([-0.61822748, -0.5043265 , -0.67367325, -0.36578176, -0.98822242,
#        -0.55936018, -0.34458897,  0.33161105, -0.4961235 ,  1.49065362,
#         1.84414206, -0.21395546,  1.87178741,  2.08935029, -0.52897686,
#        -0.45584231, -0.13508581,  0.39101478,  0.50111982, -0.33399668,
#        -0.22984819, -0.73582366, -0.73004591, -0.29973947,  0.50671171,
#        -0.51229234, -0.43852901])

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
param_grid={'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':['auto','scale'],
             'C':[10,100,1000,2000,3000]}
grid=GridSearchCV(SVC(probability=True),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\huawei\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
print("The best parameter:",grid.best_params_)
# Out:
# The best parameter: {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.041017      0.017567         0.023521        0.008627       10
# 1        0.033772      0.019193         0.026609        0.006902       10
# 2        0.025136      0.001084         0.019478        0.001260       10
# 3        0.033606      0.017966         0.029310        0.010820       10
# 4        0.022403      0.002105         0.026523        0.007496       10
# 5        0.016985      0.001130         0.018546        0.000780       10
# 6        0.026296      0.004125         0.021124        0.003222       10
# 7        0.014568      0.002278         0.020786        0.003150       10
# 8        0.015547      0.003168         0.017142        0.000679      100
# 9        0.014872      0.001447         0.020032        0.002590      100
# 10       0.020894      0.001417         0.016982        0.001596      100
# 11       0.013987      0.003216         0.016962        0.001287      100
# ...

# %%
grid_pred=grid.predict(x_test)

# %%
from sklearn.metrics import f1_score
f1_wght_average=f1_score(y_test,grid_pred,average='weighted')
print("The F1 score final:",f1_wght_average)
# Out:
# The F1 score final: 0.9834018801410106

# %%
from sklearn.metrics  import confusion_matrix
cm=confusion_matrix(y_test,grid_pred)
print(cm)
# Out:
# [[45  0]
#  [ 2 73]]

# %%
from sklearn.metrics import classification_report
report=classification_report(y_test,grid_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98        45
#         True       1.00      0.97      0.99        75
#
#     accuracy                           0.98       120
#    macro avg       0.98      0.99      0.98       120
# weighted avg       0.98      0.98      0.98       120

# %%
from sklearn.metrics import roc_auc_score
score=roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
print("The roc score:",score)
# Out:
# The roc score: 0.9997037037037036

# %%
preinput=sc.transform([[-0.61822748, -0.5043265 , -0.67367325, -0.36578176, -0.98822242,
       -0.55936018, -0.34458897,  0.33161105, -0.4961235 ,  1.49065362,
        1.84414206, -0.21395546,  1.87178741,  2.08935029, -0.52897686,
       -0.45584231, -0.13508581,  0.39101478,  0.50111982, -0.33399668,
       -0.22984819, -0.73582366, -0.73004591, -0.29973947,  0.50671171,
       -0.51229234, -0.43852901]])
result=grid.predict(preinput)
print(result)
# Out:
# [False]
# C:\Users\huawei\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
