# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('CKD.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# 0    137.528754  4.627244  12.518156  ...      False        False       False
# 1    137.528754  4.627244  10.700000  ...       True        False       False
# 2    138.000000  4.400000  12.000000  ...       True        False       False
# 3    138.000000  3.200000   8.100000  ...       True        False       False
# 4    137.528754  4.627244  11.800000  ...       True        False       False
# ..          ...       ...        ...  ...        ...          ...         ...
# 394  139.000000  3.700000  12.500000  ...       True        False       False
# 395  137.528754  4.627244   8.700000  ...       True        False       False
# 396  134.000000  2.700000   9.100000  ...       True        False       False
# 397  142.000000  5.500000   8.500000  ...       True        False       False
# 398  140.000000  5.000000  16.300000  ...       True        False       False
#
#      htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  ane_yes  classification_yes
# 0      False   False    False       True    True    False                True
# 1      False   False    False       True   False    False                True
# 2      False   False    False       True   False    False                True
# 3      False   False    False       True   False     True                True
# 4      False   False    False       True   False    False                True
# ..       ...     ...      ...        ...     ...      ...                 ...
# 394    False   False    False       True   False    False                True
# 395     True    True    False       True   False     True                True
# 396     True    True    False      False   False    False                True
# 397     True    True    False       True   False     True                True
# 398    False   False    False       True   False    False               False
#
# [399 rows x 28 columns]

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset[['classification_yes']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
# Out:
# C:\Users\huawei\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
#model training
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11, 15],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}
grid=GridSearchCV(KNeighborsClassifier(),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\huawei\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [3, 5, 7, 9, 11, 15],
#                          'weights': ['uniform', 'distance']},
#              scoring='f1_weighted', verbose=3)

# %%
print("The best parameter:",grid.best_params_)
# Out:
# The best parameter: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.010080      0.002251         0.258845        0.017310    euclidean
# 1        0.009398      0.002228         0.145877        0.098213    euclidean
# 2        0.022834      0.017710         0.039034        0.004355    euclidean
# 3        0.015415      0.012775         0.021795        0.001577    euclidean
# 4        0.011487      0.006398         0.035150        0.005114    euclidean
# 5        0.010387      0.003610         0.023061        0.001562    euclidean
# 6        0.015881      0.004283         0.031091        0.002427    euclidean
# 7        0.014621      0.008318         0.019707        0.001407    euclidean
# 8        0.019121      0.026735         0.036618        0.011788    euclidean
# 9        0.027880      0.014244         0.044801        0.013365    euclidean
# 10       0.016150      0.006499         0.060154        0.006205    euclidean
# 11       0.017632      0.004592         0.039530        0.006337    euclidean
# 12       0.027067      0.005211         0.054876        0.030160    manhattan
# 13       0.020436      0.012654         0.038681        0.014368    manhattan
# 14       0.013695      0.004534         0.028632        0.008193    manhattan
# 15       0.009612      0.004551         0.021055        0.000828    manhattan
# 16       0.009226      0.003056         0.022149        0.001915    manhattan
# 17       0.008937      0.004138         0.022866        0.004254    manhattan
# 18       0.010302      0.007411         0.020409        0.001563    manhattan
# 19       0.010895      0.005713         0.019960        0.001406    manhattan
# 20       0.011167      0.005084         0.020586        0.004119    manhattan
# 21       0.009772      0.005037         0.020222        0.000609    manhattan
# 22       0.005589      0.000576         0.018977        0.001748    manhattan
# 23       0.005450      0.001074         0.017037        0.002685    manhattan
#
#     param_n_neighbors param_weights  \
# 0                   3       uniform
# 1                   3      distance
# 2                   5       uniform
# 3                   5      distance
# 4                   7       uniform
# 5                   7      distance
# 6                   9       uniform
# 7                   9      distance
# 8                  11       uniform
# 9                  11      distance
# 10                 15       uniform
# 11                 15      distance
# 12                  3       uniform
# 13                  3      distance
# 14                  5       uniform
# 15                  5      distance
# 16                  7       uniform
# 17                  7      distance
# 18                  9       uniform
# 19                  9      distance
# 20                 11       uniform
# 21                 11      distance
# 22                 15       uniform
# 23                 15      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.964572
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.964572
# 2   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.964572
# 3   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.964572
# 4   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.964572
# 5   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.964572
# 6   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...           0.929513
# 7   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...           0.929513
# 8   {'metric': 'euclidean', 'n_neighbors': 11, 'we...           0.912029
# 9   {'metric': 'euclidean', 'n_neighbors': 11, 'we...           0.929513
# 10  {'metric': 'euclidean', 'n_neighbors': 15, 'we...           0.894531
# 11  {'metric': 'euclidean', 'n_neighbors': 15, 'we...           0.894531
# 12  {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.947015
# 13  {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.947015
# 14  {'metric': 'manhattan', 'n_neighbors': 5, 'wei...           0.982221
# 15  {'metric': 'manhattan', 'n_neighbors': 5, 'wei...           0.982221
# 16  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.964572
# 17  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.964572
# 18  {'metric': 'manhattan', 'n_neighbors': 9, 'wei...           0.982221
# 19  {'metric': 'manhattan', 'n_neighbors': 9, 'wei...           0.982221
# 20  {'metric': 'manhattan', 'n_neighbors': 11, 'we...           0.982221
# 21  {'metric': 'manhattan', 'n_neighbors': 11, 'we...           0.982221
# 22  {'metric': 'manhattan', 'n_neighbors': 15, 'we...           0.929513
# 23  {'metric': 'manhattan', 'n_neighbors': 15, 'we...           0.929513
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.982221           0.929513           0.964572
# 1            0.982221           0.929513           0.964572
# 2            0.964572           0.929513           0.964572
# 3            0.982221           0.929513           0.964572
# 4            0.947015           0.929513           0.964572
# 5            0.947015           0.929513           0.964572
# 6            0.912029           0.929513           0.964572
# 7            0.912029           0.929513           0.964572
# 8            0.894531           0.929513           0.964572
# 9            0.894531           0.929513           0.964572
# 10           0.894531           0.912029           0.929513
# 11           0.912029           0.929513           0.929513
# 12           0.982221           0.947015           0.982221
# 13           0.982221           0.947015           0.982221
# 14           0.982221           0.947015           0.982221
# 15           0.982221           0.947015           0.982221
# 16           0.947015           0.947015           0.982221
# 17           0.947015           0.947015           0.982221
# 18           0.947015           0.929513           0.964572
# 19           0.947015           0.929513           0.964572
# 20           0.929513           0.929513           0.947015
# 21           0.929513           0.929513           0.947015
# 22           0.929513           0.929513           0.947015
# 23           0.929513           0.929513           0.947015
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            1.000000         0.968176        0.023370                5
# 1            1.000000         0.968176        0.023370                5
# 2            0.963912         0.957428        0.013960               12
# 3            0.963912         0.960958        0.017180               11
# 4            0.963912         0.953917        0.013930               13
# 5            0.963912         0.953917        0.013930               13
# 6            0.963912         0.939908        0.020870               17
# 7            0.963912         0.939908        0.020870               17
# 8            0.963912         0.932911        0.027871               22
# 9            0.963912         0.936408        0.026071               19
# 10           0.963912         0.918903        0.025975               24
# 11           0.963912         0.925900        0.023010               23
# 12           1.000000         0.971694        0.021171                3
# 13           1.000000         0.971694        0.021171                3
# 14           0.981894         0.975114        0.014050                1
# 15           0.981894         0.975114        0.014050                1
# 16           0.981894         0.964543        0.015672                7
# 17           0.981894         0.964543        0.015672                7
# 18           0.981894         0.961043        0.020429                9
# 19           0.981894         0.961043        0.020429                9
# 20           0.946014         0.946855        0.019251               15
# 21           0.946014         0.946855        0.019251               15
# 22           0.946014         0.936313        0.008335               20
# 23           0.946014         0.936313        0.008335               20

# %%
grid_pred=grid.predict(x_test)

# %%
from sklearn.metrics import f1_score
f1_wght_average=f1_score(y_test,grid_pred,average='weighted')
print("The F1 score final:",f1_wght_average)
# Out:
# The F1 score final: 0.8439841725611038

# %%
from sklearn.metrics  import confusion_matrix
cm=confusion_matrix(y_test,grid_pred)
print(cm)
# Out:
# [[45  0]
#  [19 56]]

# %%
from sklearn.metrics import classification_report
report=classification_report(y_test,grid_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.70      1.00      0.83        45
#         True       1.00      0.75      0.85        75
#
#     accuracy                           0.84       120
#    macro avg       0.85      0.87      0.84       120
# weighted avg       0.89      0.84      0.84       120

# %%
from sklearn.metrics import roc_auc_score
scr=roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
print("The roc_auc_score is:",scr)
# Out:
# The roc_auc_score is: 0.9533333333333334

# %%
result=grid.predict([[20.0, 70.0, 0.0, 0.0, 123.0, 44.0, 1.0, 135.0, 3.8, 14.6, 44.0,
       5500.0, 4.8, False, False, False, False, True, True, False, False,
       False, False, False, True, False, False]])
print(result)
# Out:
# [False]
